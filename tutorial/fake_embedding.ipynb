# %%
from zul.utilities.fake_embedding import FakeEmbeddingModel

# %%
EMBEDDING = FakeEmbeddingModel(dimension=384, seed=42)

# %%
# EMBEDDING.encode("hallo").flatten()
EMBEDDING.encode("hallo").shape
# Out:
# (1, 384)
